# %%
import pandas as pd
import os
DATA_DIR = '/root/workspace/var-wold/data/memetracker/'

# %%
# %time pd.read_pickle(os.path.join(DATA_DIR, 'memetracker-top100-clean.pickle.gz'), compression='gzip')
# Out:
# CPU times: user 2.63 s, sys: 831 ms, total: 3.46 s
# Wall time: 3.46 s
#            Hyperlink_idx  Blog_idx Hyperlink                      Blog  \
# 2                    NaN        25               http://news.bbc.co.uk
# 3                    NaN        25               http://news.bbc.co.uk
# 4                    NaN        25               http://news.bbc.co.uk
# 320                  NaN        81            http://in.news.yahoo.com
# 357                  NaN        81            http://in.news.yahoo.com
# ...                  ...       ...       ...                       ...
# 141578433            NaN        45            http://groups.google.com
# 141578435            NaN        45            http://groups.google.com
# 141578485            NaN        84              http://bizjournals.com
# 141578487            NaN         0            http://blogs.myspace.com
# 141578488            NaN         0            http://blogs.myspace.com
#
#                          Date   Timestamp
# ...

# %%
# %time pd.read_csv(os.path.join(DATA_DIR, 'memetracker-top100-clean.csv.gz'), compression='gzip')
# Out:
# CPU times: user 11.8 s, sys: 1.21 s, total: 13 s
# Wall time: 13 s
#           Unnamed: 0  25 Unnamed: 2     http://news.bbc.co.uk  \
# 0                NaN  25        NaN     http://news.bbc.co.uk
# 1                NaN  25        NaN     http://news.bbc.co.uk
# 2                NaN  81        NaN  http://in.news.yahoo.com
# 3                NaN  81        NaN  http://in.news.yahoo.com
# 4                NaN  45        NaN  http://groups.google.com
# ...              ...  ..        ...                       ...
# 15168768         NaN  45        NaN  http://groups.google.com
# 15168769         NaN  45        NaN  http://groups.google.com
# 15168770         NaN  84        NaN    http://bizjournals.com
# 15168771         NaN   0        NaN  http://blogs.myspace.com
# 15168772         NaN   0        NaN  http://blogs.myspace.com
#
#           2008-08-01 00:00:01  1217548801
# 0         2008-08-01 00:00:01  1217548801
# 1         2008-08-01 00:00:01  1217548801
# ...
